# %% [markdown]
# # LAB 9

# %%
import pandas as pd
import csv

# %%
abnyc = pd.read_csv('AB_NYC_2019.csv')
abnyc.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %% [markdown]
# With this AirBnB data, you could sort through the room_type to find the type of housing you are plannning to get. For example, if you are planning to get a private room for yourself or the entire home/apartment for you and your friends/family. Another great thing to do is to look through the boroughs that you would want to rent a AirBnB from, as NYC has multiple boroughs and if you wanted to be closer to places relative to workplace or resturaunts, it would be great to look through the options for the preferred borough. Same explanation applies to the neighborhood column, as safety, which is dependent on the neighborhood, could be one of the concerns for one looking for an AirBnB. Prices is also a great variable to sort through and organize in descending/ascending order because the price range could be an important factor while trying to find a place in NYC since living in NYC is infamous for expensive housing.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.heatmap(data=abnyc.isna())

# Here we can see that the NaN values are in the columns last_review and reviews_per_month.
# Out:
# <AxesSubplot:>

# %%
abnyc['last_review'] = abnyc['last_review'].fillna(0)
abnyc['reviews_per_month'] = abnyc['reviews_per_month'].fillna(0)
abnyc

# i filled the nans with 0
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
#isolating the year from the last_review column
print(abnyc["last_review"].str[:4])

# to really see it i will print the first 20.
print(abnyc["last_review"].str[:4].head(20))
# Out:
# 0        2018
# 1        2019
# 2         NaN
# 3        2019
# 4        2018
#          ...
# 48890     NaN
# 48891     NaN
# 48892     NaN
# 48893     NaN
# 48894     NaN
# Name: last_review, Length: 48895, dtype: object
# 0     2018
# 1     2019
# 2      NaN
# 3     2019
# 4     2018
# 5     2019
# 6     2017
# 7     2019
# 8     2017
# 9     2019
# 10    2019
# 11    2019
# 12    2019
# 13    2019
# 14    2018
# 15    2019
# 16    2019
# 17    2019
# 18    2019
# 19     NaN
# Name: last_review, dtype: object

# %%
# selecting only the airbnbs in Kensington neighbourhood.
abnyc.loc[abnyc['neighbourhood'] == 'Kensington']

#https://www.interviewqs.com/ddi-code-snippets/rows-cols-python
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 258       63546                     Large and Cozy Private Bedroom     308652
# 397      125594                 SUPER BIG AND COZY PRIVATE BEDROOM     308652
# 738      267652              Private clean pleasant spacious room.     164675
# 786      282341                Kensington/Ditmas Park pied-a-terre    1471384
# ...         ...                                                ...        ...
# 47286  35676024  Private bedroom with lovely, spacious shared area  177507494
# 47295  35679309                  A unique cozy 2 bedroom apartment  268396733
# 47512  35777392    SPACIOUS STUDIO FLAT In Tree-Lined Neighborhood  117987098
# 47963  36003288           Apartment in Kensington area of Brooklyn  161196794
# 48216  36142215               SUMMER RENTAL IN SUNNY SPACIOUS ROOM   41484943
#
# ...

# %%
# Part 2
import requests 
import json

#this function uses these variables to customize the search.
def get_data(api_key, search, rating, language):

    genius = requests.get(f"https://api.giphy.com/v1/stickers/search?api_key={api_key}&q={search}&limit=25&offset=0&rating={rating}&lang={language}")
    response = genius.json()
    return response

# this gets ALL the urls based on the get_data.
def get_urls(response):
    
    values = len(response['data'])
    for i in range(0,values):
        urls = response['data'][i]['url']
        print(urls)

#this gets a specific gif based on the number.
def get_one_url(response,number):
    url = response['data'][number]['url']
    return url

#this gets the title of the gif based on the specific one.
def get_title(response, number):
    title = response['data'][number]['title']
    return title

#this gets the size of a specific gif.
def get_size(response, number):
    size = response['data'][number]['images']['original']['size']
    return size

#this gets all the bitly gif urls of our particular search.
def get_bitlygifurls(response):
    values = len(response['data'])
    for i in range(0,values):
        bitlys = response['data'][i]['bitly_gif_url']
        print(bitlys)
    
hk = get_data('kZikG8UnRqLxxIMIPebBqyg7KIyS8aXS',"hello kitty",'pg-13','en')
print(get_size(hk,2))
get_bitlygifurls(hk)
print(get_title(hk,3))
print(get_one_url(hk,4))
# Out:
# 25530
# http://gph.is/YBTRHQ
# https://gph.is/st/YkR4bdp
# https://gph.is/st/EAPrQWm
# https://gph.is/st/EpKXywm
# http://gph.is/2d62v1Q
# https://gph.is/st/EAXgA1m
# https://gph.is/st/YkRAPop
# http://gph.is/2cH6kXW
# https://gph.is/st/M24WKBm
# https://gph.is/st/MlPv8BM
# https://gph.is/st/m8rnXQM
# https://gph.is/st/myWDl0a
# http://gph.is/1URwRQr
# https://gph.is/st/E1AB5KE
# https://gph.is/st/YK4AAkm
# https://gph.is/st/ELND0XY
# https://gph.is/st/EpBOBjO
# http://gph.is/1sECTxG
# https://gph.is/st/EL23LRY
# https://gph.is/st/MXox19L
# https://gph.is/st/ENarzpm
# https://gph.is/st/YrpXzlo
# https://gph.is/st/m7XPbgE
# https://gph.is/st/YoJxR9r
# https://gph.is/st/meegzJA
# Cute Sticker by Hello Kitty
# https://giphy.com/stickers/sanrio-hBFR4rbtBBJiE
