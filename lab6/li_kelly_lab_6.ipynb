# %%
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import csv
import pandas as pd

# %%
PATH = Service("/Users/vanilla/Downloads/chromedriver_mac64/chromedriver.exe")
driver = webdriver.Chrome(service=PATH)

driver.get("https://www.binghamton-ny.gov/home")


gov = driver.find_element(By.XPATH,'//*[@id="dropdownrootitem3"]/a')
dep = driver.find_element(By.XPATH, '//*[@id="dropdownrootitem3"]/div/div/ul[1]/li/a')

actions=ActionChains(driver)
actions.move_to_element(gov)
actions.click(gov)
actions.click(dep)

actions.perform()

try:
    link=WebDriverWait(driver,10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="widget_4_33_127"]/ul/li[16]/a')))
    link.click()
    link2=WebDriverWait(driver,10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="leftNav_1038_0_145"]/ul/li/ul/li[14]/ul/li/a')))
    link2.click()
    
    rows=1+len(driver.find_elements(By.XPATH, '//*[@id="ColumnUserControl4"]/div[2]/table/tbody/tr'))
    cols=4

    #making the csv file
    csv_file = open('bingjobs.csv','w',newline='',encoding="utf-8")
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Job Title", "Time", "Application Deadline", "Salary"])

#how to scrape a table with selenium:
#https://www.geeksforgeeks.org/scrape-table-from-website-using-python-selenium/

    for r in range(1, rows+1):
        job = driver.find_element(By.XPATH, '//*[@id="ColumnUserControl4"]/div[2]/table/tbody/tr['+str(r)+']/td[1]/a').text
        time = driver.find_element(By.XPATH, '//*[@id="ColumnUserControl4"]/div[2]/table/tbody/tr['+str(r)+']/td[2]').text
        appd = driver.find_element(By.XPATH, '//*[@id="ColumnUserControl4"]/div[2]/table/tbody/tr['+str(r)+']/td[3]').text   
        salary = driver.find_element(By.XPATH, '//*[@id="ColumnUserControl4"]/div[2]/table/tbody/tr['+str(r)+']/td[4]').text   
        print(job,time,appd,salary)
        
        csv_writer.writerow([job,time,appd,salary])
    
    csv_file.close()

except:
    driver.quit()
# Out:
# Animal Control Officer Full Time Open Until Filled $45,228.00 per Year
# Assistant Engineer Full Time Open Until Filled $38,127 - $45,062 per Year
# Building Inspector II Full Time Open Until Filled $42,436 per Year
# City Engineer Full Time Open Until Filled Not Specified
# Code Inspector Full Time Open Until Filled $33,632 per Year*
# Commissioner of Public Works Full Time Open Until Filled Not Specified
# Crossing Guard Part Time Open Until Filled $43.75 per Day
# Director of Police Department Community Outreach and Recruitment Full Time Open Until Filled $66,950.00 per Year
# First Deputy Commissioner of Public Works Full Time Open Until Filled $61,730.00 per Year
# Laboratory Technician (Sanitary Services) Full Time Open Until Filled $29,406.00 per Year
# Staff Accountant Full Time Open Until Filled Up to $59,000 per Year
# Street Maintainer Full Time Open Until Filled $18.36 Per Hour
# Water & Sewer Systems Maintainer Full Time Open Until Filled $20.71 per Hour
# ...

# %%
jobs = pd.read_csv('bingjobs.csv')
jobs
# Out:
#                                             Job Title       Time  \
# 0                              Animal Control Officer  Full Time
# 1                                  Assistant Engineer  Full Time
# 2                               Building Inspector II  Full Time
# 3                                       City Engineer  Full Time
# 4                                      Code Inspector  Full Time
# 5                        Commissioner of Public Works  Full Time
# 6                                      Crossing Guard  Part Time
# 7   Director of Police Department Community Outrea...  Full Time
# 8           First Deputy Commissioner of Public Works  Full Time
# 9           Laboratory Technician (Sanitary Services)  Full Time
# 10                                   Staff Accountant  Full Time
# 11                                  Street Maintainer  Full Time
# 12                   Water & Sewer Systems Maintainer  Full Time
# ...
